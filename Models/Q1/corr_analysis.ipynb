# %%
# packages
import pandas as pd

# %%
data = pd.read_csv('data/q1_cleand.csv')
data['percentage'] = data['Hard']/data['Reported']
data
# Out:
#            Date  Contest number   Word  Reported    Hard  1 try  2 tries  \
# 0    2022-12-31           560.0  manly   20380.0  1899.0    0.0      2.0
# 1    2022-12-30           559.0  molar   21204.0  1973.0    0.0      4.0
# 2    2022-12-29           558.0  havoc   20001.0  1919.0    0.0      2.0
# 3    2022-12-28           557.0  impel   20160.0  1937.0    0.0      3.0
# 4    2022-12-27           556.0  condo   20879.0  2012.0    0.0      2.0
# ..          ...             ...    ...       ...     ...    ...      ...
# 351  2022-01-11           206.0  drink  153880.0  3017.0    1.0      9.0
# 352  2022-01-10           205.0  query  107134.0  2242.0    1.0      4.0
# 353  2022-01-09           204.0  gorge   91477.0  1913.0    1.0      3.0
# 354  2022-01-08           203.0  crank  101503.0  1763.0    1.0      5.0
# 355  2022-01-07           202.0  slump   80630.0  1362.0    1.0      3.0
#
#      3 tries  4 tries  5 tries  ...  y  z  Length  vowel  consonants  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
percentage_scalar = np.array(data['percentage']).reshape(-1, 1)
data['percentage_scalar'] = scaler.fit_transform(percentage_scalar)
vowel_rate_scalar = np.array(data['vowel_rate']).reshape(-1, 1)
data['vowel_rate_scalar'] = scaler.fit_transform(vowel_rate_scalar)
max_repeat_scalar = np.array(data['max_repeat']).reshape(-1, 1)
data['max_repeat_scalar'] = scaler.fit_transform(max_repeat_scalar)

# %%
corr_matrix = data[['percentage', 'vowel_rate','word_vc_structure','max_repeat', 'familiarity']].corr()

# %%
import seaborn as sns
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>
